# %% [markdown]
# <a href="https://colab.research.google.com/github/jfernandez37/495Project/blob/main/495_search_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import os
#fileLocation = r"C:\Users\wgoco\OneDrive\Desktop\VS_CODE\Python"
#os.chdir(fileLocation)
stuff=sio.loadmat('iFarmData(2015)_1_28_2019.mat')

# %%
 #finds a country given off a country code 
countryCode = input("Enter a country code: ")
for i in range(218):
  countryName = str(stuff['FAOSTAT_CoName_FAO'][i])
  #print(countryName)
  testSplit = countryName.split("[")
  countryName =testSplit[2].split("]")[0]

  countryID = str(stuff['FAOSTAT_CoCODE_FAO'][i])
  countryID=countryID.replace("[","")
  countryID=countryID.replace("]","")

  #if(countryCode==countryID):
    #print(countryID+" "+countryName+" "+str(i))
  print(countryID+" "+countryName+" index:1"+str(i))

#searches by country name
countryNa = input("Enter a country name: ")
for i in range(218):
  countryName = str(stuff['FAOSTAT_CoName_FAO'][i])
  #print(countryName)
  testSplit = countryName.split("[")
  countryName =testSplit[2].split("]")[0]

  countryID = str(stuff['FAOSTAT_CoCODE_FAO'][i])
  countryID=countryID.replace("[","")
  countryID=countryID.replace("]","")
  countryName=countryName.replace("'","")

  if(countryNa == countryName):
    print(countryID," ",countryName)

print("DONE")
# Out:
# Enter a country code: 1
# 2 'Afghanistan' index:10
# 3 'Albania' index:11
# 4 'Algeria' index:12
# 5 'American Samoa' index:13
# 7 'Angola' index:14
# 8 'Antigua and Barbuda' index:15
# 9 'Argentina' index:16
# 1 'Armenia' index:17
# 10 'Australia' index:18
# 11 'Austria' index:19
# 52 'Azerbaijan' index:110
# 12 'Bahamas' index:111
# 13 'Bahrain' index:112
# 16 'Bangladesh' index:113
# 14 'Barbados' index:114
# 57 'Belarus' index:115
# 255 'Belgium' index:116
# 15 'Belgium-Luxembourg' index:117
# 23 'Belize' index:118
# 53 'Benin' index:119
# 17 'Bermuda' index:120
# 18 'Bhutan' index:121
# 19 'Bolivia (Plurinational State of)' index:122
# 80 'Bosnia and Herzegovina' index:123
# 20 'Botswana' index:124
# 21 'Brazil' index:125
# 239 'British Virgin Islands' index:126
# 26 'Brunei Darussalam' index:127
# 27 'Bulgaria' index:128
# 233 'Burkina Faso' index:129
# 29 'Burundi' index:130
# 115 'Cambodia' index:131
# 32 'Cameroon' index:132
# 33 'Canada' index:133
# 35 'Cape Verde' index:134
# 36 'Cayman Islands' index:135
# 37 'Central African Republic' index:136
# 39 'Chad' index:137
# 40 'Chile' index:138
# 351 'China' index:139
# 44 'Colombia' index:140
# 45 'Comoros' index:141
# 46 'Congo' index:142
# 47 'Cook Islands' index:143
# 48 'Costa Rica' index:144
# 98 'Croatia' index:145
# 49 'Cuba' index:146
# 50 'Cyprus' index:147
# 167 'Czech Republic' index:148
# 51 'Czechoslovakia' index:149
# 107 'C?te dIvoire' index:150
# 116 'Democratic Peoples Republic of Korea' index:151
# 250 'Democratic Republic of the Congo' index:152
# 54 'Denmark' index:153
# 72 'Djibouti' index:154
# 55 'Dominica' index:155
# 56 'Dominican Republic' index:156
# 58 'Ecuador' index:157
# 59 'Egypt' index:158
# 60 'El Salvador' index:159
# 61 'Equatorial Guinea' index:160
# 178 'Eritrea' index:161
# 63 'Estonia' index:162
# 238 'Ethiopia' index:163
# 62 'Ethiopia PDR' index:164
# 64 'Faroe Islands' index:165
# 66 'Fiji' index:166
# 67 'Finland' index:167
# 68 'France' index:168
# 69 'French Guiana' index:169
# 70 'French Polynesia' index:170
# 74 'Gabon' index:171
# 75 'Gambia' index:172
# 73 'Georgia' index:173
# 79 'Germany' index:174
# 81 'Ghana' index:175
# 84 'Greece' index:176
# 86 'Grenada' index:177
# 87 'Guadeloupe' index:178
# 88 'Guam' index:179
# 89 'Guatemala' index:180
# 90 'Guinea' index:181
# 175 'Guinea-Bissau' index:182
# 91 'Guyana' index:183
# 93 'Haiti' index:184
# 95 'Honduras' index:185
# 97 'Hungary' index:186
# 99 'Iceland' index:187
# 100 'India' index:188
# 101 'Indonesia' index:189
# 102 'Iran (Islamic Republic of)' index:190
# 103 'Iraq' index:191
# 104 'Ireland' index:192
# 105 'Israel' index:193
# 106 'Italy' index:194
# 109 'Jamaica' index:195
# 110 'Japan' index:196
# 112 'Jordan' index:197
# 108 'Kazakhstan' index:198
# 114 'Kenya' index:199
# 83 'Kiribati' index:1100
# 118 'Kuwait' index:1101
# 113 'Kyrgyzstan' index:1102
# 120 'Lao Peoples Democratic Republic' index:1103
# 119 'Latvia' index:1104
# 121 'Lebanon' index:1105
# 122 'Lesotho' index:1106
# 123 'Liberia' index:1107
# 124 'Libya' index:1108
# 125 'Liechtenstein' index:1109
# 126 'Lithuania' index:1110
# 256 'Luxembourg' index:1111
# 129 'Madagascar' index:1112
# 130 'Malawi' index:1113
# 131 'Malaysia' index:1114
# 132 'Maldives' index:1115
# 133 'Mali' index:1116
# 134 'Malta' index:1117
# 127 'Marshall Islands' index:1118
# 135 'Martinique' index:1119
# 136 'Mauritania' index:1120
# 137 'Mauritius' index:1121
# 138 'Mexico' index:1122
# 145 'Micronesia (Federated States of)' index:1123
# 141 'Mongolia' index:1124
# 273 'Montenegro' index:1125
# 142 'Montserrat' index:1126
# 143 'Morocco' index:1127
# 144 'Mozambique' index:1128
# 28 'Myanmar' index:1129
# 147 'Namibia' index:1130
# 148 'Nauru' index:1131
# 149 'Nepal' index:1132
# 150 'Netherlands' index:1133
# 153 'New Caledonia' index:1134
# 156 'New Zealand' index:1135
# 157 'Nicaragua' index:1136
# 158 'Niger' index:1137
# 159 'Nigeria' index:1138
# 160 'Niue' index:1139
# 162 'Norway' index:1140
# 299 'Occupied Palestinian Territory' index:1141
# 221 'Oman' index:1142
# 164 'Pacific Islands Trust Territory' index:1143
# 165 'Pakistan' index:1144
# 166 'Panama' index:1145
# 168 'Papua New Guinea' index:1146
# 169 'Paraguay' index:1147
# 170 'Peru' index:1148
# 171 'Philippines' index:1149
# 173 'Poland' index:1150
# 174 'Portugal' index:1151
# 177 'Puerto Rico' index:1152
# 179 'Qatar' index:1153
# 117 'Republic of Korea' index:1154
# 146 'Republic of Moldova' index:1155
# 183 'Romania' index:1156
# 185 'Russian Federation' index:1157
# 184 'Rwanda' index:1158
# 182 'R?union' index:1159
# 187 'Saint Helena' index:1160
# 188 'Saint Kitts and Nevis' index:1161
# 189 'Saint Lucia' index:1162
# 190 'Saint Pierre and Miquelon' index:1163
# 191 'Saint Vincent and the Grenadines' index:1164
# 244 'Samoa' index:1165
# 193 'Sao Tome and Principe' index:1166
# 194 'Saudi Arabia' index:1167
# 195 'Senegal' index:1168
# 272 'Serbia' index:1169
# 186 'Serbia and Montenegro' index:1170
# 196 'Seychelles' index:1171
# 197 'Sierra Leone' index:1172
# 200 'Singapore' index:1173
# 199 'Slovakia' index:1174
# 198 'Slovenia' index:1175
# 25 'Solomon Islands' index:1176
# 201 'Somalia' index:1177
# 202 'South Africa' index:1178
# 203 'Spain' index:1179
# 38 'Sri Lanka' index:1180
# 206 'Sudan (former)' index:1181
# 207 'Suriname' index:1182
# 209 'Swaziland' index:1183
# 210 'Sweden' index:1184
# 211 'Switzerland' index:1185
# 212 'Syrian Arab Republic' index:1186
# 208 'Tajikistan' index:1187
# 216 'Thailand' index:1188
# 154 'The former Yugoslav Republic of Macedonia' index:1189
# 176 'Timor-Leste' index:1190
# 217 'Togo' index:1191
# 218 'Tokelau' index:1192
# 219 'Tonga' index:1193
# 220 'Trinidad and Tobago' index:1194
# 222 'Tunisia' index:1195
# 223 'Turkey' index:1196
# 213 'Turkmenistan' index:1197
# 227 'Tuvalu' index:1198
# 228 'USSR' index:1199
# 226 'Uganda' index:1200
# 230 'Ukraine' index:1201
# 225 'United Arab Emirates' index:1202
# 229 'United Kingdom' index:1203
# 215 'United Republic of Tanzania' index:1204
# 240 'United States Virgin Islands' index:1205
# 231 'United States of America' index:1206
# 234 'Uruguay' index:1207
# 235 'Uzbekistan' index:1208
# 155 'Vanuatu' index:1209
# 236 'Venezuela (Bolivarian Republic of)' index:1210
# 237 'Viet Nam' index:1211
# 243 'Wallis and Futuna Islands' index:1212
# 205 'Western Sahara' index:1213
# 249 'Yemen' index:1214
# 248 'Yugoslav SFR' index:1215
# 251 'Zambia' index:1216
# 181 'Zimbabwe' index:1217
# Enter a country name: 1
# DONE
