# %% [markdown]
# <a href="https://colab.research.google.com/github/jfernandez37/495Project/blob/main/495_search_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import os
#fileLocation = r"C:\Users\wgoco\OneDrive\Desktop\VS_CODE\Python"
#os.chdir(fileLocation)
stuff=sio.loadmat('iFarmData(2015)_1_28_2019.mat')

# %%
 #finds a country given off a country code 
countryCode = input("Enter a country code: ")
for i in range(218):
  countryName = str(stuff['FAOSTAT_CoName_FAO'][i])
  #print(countryName)
  testSplit = countryName.split("[")
  countryName =testSplit[2].split("]")[0]

  countryID = str(stuff['FAOSTAT_CoCODE_FAO'][i])
  countryID=countryID.replace("[","")
  countryID=countryID.replace("]","")

  #if(countryCode==countryID):
    #print(countryID+" "+countryName+" "+str(i))
  print(countryID+" "+countryName+" "+str(i))

#searches by country name
countryNa = input("Enter a country name: ")
for i in range(218):
  countryName = str(stuff['FAOSTAT_CoName_FAO'][i])
  #print(countryName)
  testSplit = countryName.split("[")
  countryName =testSplit[2].split("]")[0]

  countryID = str(stuff['FAOSTAT_CoCODE_FAO'][i])
  countryID=countryID.replace("[","")
  countryID=countryID.replace("]","")
  countryName=countryName.replace("'","")

  if(countryNa == countryName):
    print(countryID," ",countryName)

print("DONE")
# Out:
# Enter a country code: 4
# 2 'Afghanistan' 0
# 3 'Albania' 1
# 4 'Algeria' 2
# 5 'American Samoa' 3
# 7 'Angola' 4
# 8 'Antigua and Barbuda' 5
# 9 'Argentina' 6
# 1 'Armenia' 7
# 10 'Australia' 8
# 11 'Austria' 9
# 52 'Azerbaijan' 10
# 12 'Bahamas' 11
# 13 'Bahrain' 12
# 16 'Bangladesh' 13
# 14 'Barbados' 14
# 57 'Belarus' 15
# 255 'Belgium' 16
# 15 'Belgium-Luxembourg' 17
# 23 'Belize' 18
# 53 'Benin' 19
# 17 'Bermuda' 20
# 18 'Bhutan' 21
# 19 'Bolivia (Plurinational State of)' 22
# 80 'Bosnia and Herzegovina' 23
# 20 'Botswana' 24
# 21 'Brazil' 25
# 239 'British Virgin Islands' 26
# 26 'Brunei Darussalam' 27
# 27 'Bulgaria' 28
# 233 'Burkina Faso' 29
# 29 'Burundi' 30
# 115 'Cambodia' 31
# 32 'Cameroon' 32
# 33 'Canada' 33
# 35 'Cape Verde' 34
# 36 'Cayman Islands' 35
# 37 'Central African Republic' 36
# 39 'Chad' 37
# 40 'Chile' 38
# 351 'China' 39
# 44 'Colombia' 40
# 45 'Comoros' 41
# 46 'Congo' 42
# 47 'Cook Islands' 43
# 48 'Costa Rica' 44
# 98 'Croatia' 45
# 49 'Cuba' 46
# 50 'Cyprus' 47
# 167 'Czech Republic' 48
# 51 'Czechoslovakia' 49
# 107 'C?te dIvoire' 50
# 116 'Democratic Peoples Republic of Korea' 51
# 250 'Democratic Republic of the Congo' 52
# 54 'Denmark' 53
# 72 'Djibouti' 54
# 55 'Dominica' 55
# 56 'Dominican Republic' 56
# 58 'Ecuador' 57
# 59 'Egypt' 58
# 60 'El Salvador' 59
# 61 'Equatorial Guinea' 60
# 178 'Eritrea' 61
# 63 'Estonia' 62
# 238 'Ethiopia' 63
# 62 'Ethiopia PDR' 64
# 64 'Faroe Islands' 65
# 66 'Fiji' 66
# 67 'Finland' 67
# 68 'France' 68
# 69 'French Guiana' 69
# 70 'French Polynesia' 70
# 74 'Gabon' 71
# 75 'Gambia' 72
# 73 'Georgia' 73
# 79 'Germany' 74
# 81 'Ghana' 75
# 84 'Greece' 76
# 86 'Grenada' 77
# 87 'Guadeloupe' 78
# 88 'Guam' 79
# 89 'Guatemala' 80
# 90 'Guinea' 81
# 175 'Guinea-Bissau' 82
# 91 'Guyana' 83
# 93 'Haiti' 84
# 95 'Honduras' 85
# 97 'Hungary' 86
# 99 'Iceland' 87
# 100 'India' 88
# 101 'Indonesia' 89
# 102 'Iran (Islamic Republic of)' 90
# 103 'Iraq' 91
# 104 'Ireland' 92
# 105 'Israel' 93
# 106 'Italy' 94
# 109 'Jamaica' 95
# 110 'Japan' 96
# 112 'Jordan' 97
# 108 'Kazakhstan' 98
# 114 'Kenya' 99
# 83 'Kiribati' 100
# 118 'Kuwait' 101
# 113 'Kyrgyzstan' 102
# 120 'Lao Peoples Democratic Republic' 103
# 119 'Latvia' 104
# 121 'Lebanon' 105
# 122 'Lesotho' 106
# 123 'Liberia' 107
# 124 'Libya' 108
# 125 'Liechtenstein' 109
# 126 'Lithuania' 110
# 256 'Luxembourg' 111
# 129 'Madagascar' 112
# 130 'Malawi' 113
# 131 'Malaysia' 114
# 132 'Maldives' 115
# 133 'Mali' 116
# 134 'Malta' 117
# 127 'Marshall Islands' 118
# 135 'Martinique' 119
# 136 'Mauritania' 120
# 137 'Mauritius' 121
# 138 'Mexico' 122
# 145 'Micronesia (Federated States of)' 123
# 141 'Mongolia' 124
# 273 'Montenegro' 125
# 142 'Montserrat' 126
# 143 'Morocco' 127
# 144 'Mozambique' 128
# 28 'Myanmar' 129
# 147 'Namibia' 130
# 148 'Nauru' 131
# 149 'Nepal' 132
# 150 'Netherlands' 133
# 153 'New Caledonia' 134
# 156 'New Zealand' 135
# 157 'Nicaragua' 136
# 158 'Niger' 137
# 159 'Nigeria' 138
# 160 'Niue' 139
# 162 'Norway' 140
# 299 'Occupied Palestinian Territory' 141
# 221 'Oman' 142
# 164 'Pacific Islands Trust Territory' 143
# 165 'Pakistan' 144
# 166 'Panama' 145
# 168 'Papua New Guinea' 146
# 169 'Paraguay' 147
# 170 'Peru' 148
# 171 'Philippines' 149
# 173 'Poland' 150
# 174 'Portugal' 151
# 177 'Puerto Rico' 152
# 179 'Qatar' 153
# 117 'Republic of Korea' 154
# 146 'Republic of Moldova' 155
# 183 'Romania' 156
# 185 'Russian Federation' 157
# 184 'Rwanda' 158
# 182 'R?union' 159
# 187 'Saint Helena' 160
# 188 'Saint Kitts and Nevis' 161
# 189 'Saint Lucia' 162
# 190 'Saint Pierre and Miquelon' 163
# 191 'Saint Vincent and the Grenadines' 164
# 244 'Samoa' 165
# 193 'Sao Tome and Principe' 166
# 194 'Saudi Arabia' 167
# 195 'Senegal' 168
# 272 'Serbia' 169
# 186 'Serbia and Montenegro' 170
# 196 'Seychelles' 171
# 197 'Sierra Leone' 172
# 200 'Singapore' 173
# 199 'Slovakia' 174
# 198 'Slovenia' 175
# 25 'Solomon Islands' 176
# 201 'Somalia' 177
# 202 'South Africa' 178
# 203 'Spain' 179
# 38 'Sri Lanka' 180
# 206 'Sudan (former)' 181
# 207 'Suriname' 182
# 209 'Swaziland' 183
# 210 'Sweden' 184
# 211 'Switzerland' 185
# 212 'Syrian Arab Republic' 186
# 208 'Tajikistan' 187
# 216 'Thailand' 188
# 154 'The former Yugoslav Republic of Macedonia' 189
# 176 'Timor-Leste' 190
# 217 'Togo' 191
# 218 'Tokelau' 192
# 219 'Tonga' 193
# 220 'Trinidad and Tobago' 194
# 222 'Tunisia' 195
# 223 'Turkey' 196
# 213 'Turkmenistan' 197
# 227 'Tuvalu' 198
# 228 'USSR' 199
# 226 'Uganda' 200
# 230 'Ukraine' 201
# 225 'United Arab Emirates' 202
# 229 'United Kingdom' 203
# 215 'United Republic of Tanzania' 204
# 240 'United States Virgin Islands' 205
# 231 'United States of America' 206
# 234 'Uruguay' 207
# 235 'Uzbekistan' 208
# 155 'Vanuatu' 209
# 236 'Venezuela (Bolivarian Republic of)' 210
# 237 'Viet Nam' 211
# 243 'Wallis and Futuna Islands' 212
# 205 'Western Sahara' 213
# 249 'Yemen' 214
# 248 'Yugoslav SFR' 215
# 251 'Zambia' 216
# 181 'Zimbabwe' 217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-07deba8ef253> in <module>()
#      16
#      17 #searches by country name
# ---> 18 countryNa = input("Enter a country name: ")
#      19 for i in range(218):
#      20  countryName = str(stuff['FAOSTAT_CoName_FAO'][i])
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
